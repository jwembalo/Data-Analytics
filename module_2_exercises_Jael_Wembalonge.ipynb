# %% [markdown]
# <a href="https://colab.research.google.com/github/jwembalo/Data-Analytics/blob/main/module_2_exercises_Jael_Wembalonge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 2 Exercises

# %% [markdown]
# ## Question 1

# %%
# In the following string object str, use find and string slicing to extract the portion of 
# the string after the colon character and then use the float function to convert the 
# extracted string into a floating point number.

# %%
str = 'X-DSPAM-Confidence:0.8475'

# %%
# Answer:
pos = str.find(':')
print(float(str[pos+1:]))
# Out:
# 0.8475

# %% [markdown]
# ## Question 2

# %%
# Download the following text file from www.py4e.com/code3/mbox-short.txt
# Write a Python program to read through this text file and print the contents of the file (line by line) 
# all in upper case.

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-59b757f8-cb1b-4aeb-807f-76b99c5a9de1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59b757f8-cb1b-4aeb-807f-76b99c5a9de1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mbox-short.txt to mbox-short.txt
# ...

# %%
myfile = open('mbox-short.txt')
for line in myfile:
  line = line.rstrip()
  print(line.upper())
# Out:
# FROM STEPHEN.MARQUARD@UCT.AC.ZA SAT JAN  5 09:14:16 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.90])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 SAT, 05 JAN 2008 09:14:16 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 SAT, 05 JAN 2008 09:14:16 -0500
# RECEIVED: FROM HOLES.MR.ITD.UMICH.EDU (HOLES.MR.ITD.UMICH.EDU [141.211.14.79])
# 	BY FLAWLESS.MAIL.UMICH.EDU () WITH ESMTP ID M05EEFR1013674;
# 	SAT, 5 JAN 2008 09:14:15 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY HOLES.MR.ITD.UMICH.EDU ID 477F90B0.2DB2F.12494 ;
# 	 5 JAN 2008 09:14:10 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 5F919BC2F2;
# 	SAT,  5 JAN 2008 14:10:05 +0000 (GMT)
# MESSAGE-ID: <200801051412.M05ECIAH010327@NAKAMURA.UITS.IUPUI.EDU>
# ...

# %% [markdown]
# ## Question 3

# %%
# Write a Python program that prompts the user for a list of numbers and prints out the maximum and minimum 
# of the numbers at the end when the user enters “done”. Write the program to store the numbers the 
# user enters in a list and use the max() and min() functions to compute the maximum and minimum 
# numbers after the loop completes.

# Enter a number: 6 
# Enter a number: 2 
# Enter a number: 9 
# Enter a number: 3 
# Enter a number: 5 
# Enter a number: done 
# Maximum: 9.0 Minimum: 2.0

# %%
print("Enter a list of numbers to find out its maximum and minimum values. Enter done when you are done.")
numlist = []
num = input("Enter a number: ")
while num != "done":
  num = float(num)
  numlist.append(num)
  num = input("Enter a number: ")
print('Maximum: ', max(numlist), ' Minimum: ', min(numlist))
# Out:
# Enter a list of numbers to find out its maximum and minimum values. Enter done when you are done.
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Enter a number: done
# Maximum:  5.0  Minimum:  1.0
